# %% [markdown]
# # PREDICT RESIDUALS after Smoothed MONTHLY TREND removed on ROLLING FEATURE data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('bmh')

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_absolute_error

# %%
# read in pickled features
df_sj = pd.read_pickle('./datasets/all_sj.pkl')
df_iq = pd.read_pickle('./datasets/all_iq.pkl')

total_cases = pd.read_csv('./datasets/dengue_labels_train.csv')
cases_sj = total_cases[total_cases['city'] == 'sj']['total_cases']
cases_iq = total_cases[total_cases['city'] == 'iq']['total_cases']

# create month variable
df_sj['month'] = df_sj.index.month
df_iq['month'] = df_iq.index.month

# create mean ndvi
df_sj['ndvi_mean'] = (df_sj['ndvi_ne'] + df_sj['ndvi_nw'] + df_sj['ndvi_se'] + df_sj['ndvi_sw']) / 4.0
df_iq['ndvi_mean'] = (df_iq['ndvi_ne'] + df_iq['ndvi_nw'] + df_iq['ndvi_se'] + df_iq['ndvi_sw']) / 4.0

# %% [markdown]
# ## Train-Validation-Test Split
# Because this is time-series data and the features set is dependent on the past, the train test split is very delicate. The validation and test feature set will actually draw from data in the past (rolling mean, std, etc.). Therefore, when creating the model, the entire dataset must be used. But I must be careful not to train the model on data from the 'future'.

# %%
# train test split
#sj

# choose split dates
sj_valid_split = '2003-4-20'
sj_test_split = '2008-4-27' # this will split between pre and post submission dates

# split into train, valid, test (no y)
sj_train = df_sj.loc[:sj_valid_split]
sj_Xtrain = sj_train
sj_ytrain = cases_sj[:len(sj_train)]

sj_valid = df_sj.loc[sj_valid_split : sj_test_split]
sj_Xvalid = sj_valid
sj_yvalid = cases_sj[len(sj_train):]

sj_test = df_sj.loc[sj_test_split:]
sj_Xtest = sj_test

print len(sj_train), len(sj_Xtrain), len(sj_ytrain)
print len(sj_valid), len(sj_Xvalid), len(sj_yvalid)
print len(sj_test), len(sj_Xtest)
# Out:
# 675 675 675
# 261 261 261
# 260 260

# %%
#iq

# choose split dates
iq_valid_split = '2007-7-01'
iq_test_split = '2010-7-01' # this will split between pre and post submission dates

# split
iq_train = df_iq.loc[:iq_valid_split]
iq_Xtrain = iq_train
iq_ytrain = cases_iq[:len(iq_Xtrain)]

iq_valid = df_iq.loc[iq_valid_split : iq_test_split]
iq_Xvalid = iq_valid
iq_yvalid = cases_iq[len(iq_train):]

iq_test = df_iq.loc[iq_test_split:]
iq_Xtest = iq_test

# check the lengths
print len(iq_train), len(iq_Xtrain), len(iq_ytrain)
print len(iq_valid), len(iq_Xvalid), len(iq_yvalid)
print len(iq_test), len(iq_Xtest)
# Out:
# 364 364 364
# 156 156 156
# 156 156

# %% [markdown]
# ## SJ

# %%
print len(pd.get_dummies(sj_Xtrain['month'], prefix='month')), len(sj_ytrain.values)
print len(pd.get_dummies(sj_Xvalid['month'], prefix='month')), len(sj_yvalid.values)
# Out:
# 675 675
# 261 261

# %%
# sj monthly trend

lr_sj = LinearRegression()
X = pd.get_dummies(sj_Xtrain['month'], prefix='month')
y = sj_ytrain.values

lr_sj.fit(X, y)
monthly_trend_train = pd.Series(lr_sj.predict(X)).rolling(3, min_periods = 1).mean()
sj_residuals_train = y - monthly_trend_train


# on validation data
# note: monthly trend does not need previous weeks data, so this can use the validation set
Xtest = pd.get_dummies(sj_Xvalid['month'], prefix='month')
ytest = sj_yvalid.values
monthly_trend_valid = pd.Series(lr_sj.predict(Xtest)).rolling(3, min_periods=1).mean()
sj_residuals_test = ytest - monthly_trend_valid

# plot
plt.plot(lr_sj.predict(Xtest))
plt.plot(monthly_trend_valid)
plt.plot(ytest)
plt.show()

print mean_absolute_error(lr_sj.predict(Xtest), ytest)
print mean_absolute_error(monthly_trend_valid, ytest)
# Out:
# 24.5775862069
# 25.4070881226

# %%
# Find the residuals of the monthly trend

plt.figure(figsize=(16, 4))
plt.plot(sj_residuals_test, label = 'residuals', linewidth = 3)
plt.plot(ytest, 'g-*', alpha = .4, label = 'true values')
plt.plot(monthly_trend_valid, alpha = .4, label = 'monthly trend')
plt.title('True Values, Monthly Trend, and Residuals of Dengue Cases in San Juan, Puerto Rico')
plt.legend()
print np.mean(sj_residuals_test)

print len(sj_residuals_train), len(sj_residuals_test)

## PREDICT THE BLUE!!!
# Out:
# -16.0833333333
# 675 261

# %%
# get all residuals
lr_sj_month = LinearRegression()
X_months = pd.get_dummies(df_sj['month'], prefix='month')[:936]
Xtest_months = pd.get_dummies(df_sj['month'], prefix='month')[936:]
y = cases_sj.values
lr_sj_month.fit(X_months, y)
monthly_trend = pd.Series(lr_sj_month.predict(X_months)).rolling(3, min_periods=1).mean()
sj_residuals_all = y - monthly_trend

# plot all residuals
plt.figure(figsize=(32, 4))
plt.plot(df_sj[:936].index, sj_residuals_all, label = 'residuals')
plt.xlabel('Date', fontsize = 25)
plt.ylabel('Number of Cases', fontsize=25)
plt.title('Residuals of Dengue Cases in San Juan, Puerto Rico', fontsize = 35)

# %%
# Histogram of Residuals
plt.figure(figsize=(10,6))
plt.hist(sj_residuals_all, bins = 50)
plt.xlabel('Difference between Actual Cases and Monthly Trend (Residuals)', fontsize=15)
plt.title('Distribution of Residuals', fontsize = 25);

# %% [markdown]
# ### Explore the of correlations on rolling mean/std windows and shifted days back

# %% [markdown]
# ### Rolling Mean

# %%
# Plot sum of correlation between rolling mean of all features and residuals
# create df of correlation between feature and resid at each rolling mean
df_scores = pd.DataFrame()
for i in range (2, 80):
    df = sj_train.drop(['month', 'weekofyear', 'month'], axis = 1)
    df = df.rolling(i, min_periods=1).mean()
    df['resid'] = sj_residuals_train.values
    df_corr = df.corr()
    df_scores[str(i)] = df_corr['resid']

# %%
# create df of max absolute value of corr and the window
feature = []
abs_corr = []
window = []

for i in df_scores.T.drop('resid', axis = 1).columns:
    feature.append(i)
    abs_corr.append(max(abs(df_scores.T[i])))
    window.append(df_scores.T[abs(df_scores.T[i]) == max(abs(df_scores.T[i]))].index[0])

scores_df = pd.DataFrame([feature, abs_corr, window]).T
scores_df.columns = ('feature', 'abs_corr', 'window')
scores_df.sort_values('abs_corr', ascending = False)
# Out:
#                                   feature   abs_corr window
# 12           reanalysis_sat_precip_amt_mm   0.396155     57
# 4                    precipitation_amt_mm   0.396155     57
# 19                      station_precip_mm   0.360348     63
# 2                                 ndvi_se   0.355405     22
# 16                station_diur_temp_rng_c   0.198901     66
# 14                      reanalysis_tdtr_k    0.18268     79
# 17                     station_max_temp_c   0.178483     54
# 15                     station_avg_temp_c   0.176856     57
# 18                     station_min_temp_c   0.145271     53
# 3                                 ndvi_sw   0.130776     32
# 10        reanalysis_precip_amt_kg_per_m2   0.122934     41
# 20                              ndvi_mean   0.107176     23
# 9               reanalysis_min_air_temp_k  0.0989916     56
# 8               reanalysis_max_air_temp_k  0.0745497      2
# 0                                 ndvi_ne  0.0719088      8
# 5                   reanalysis_air_temp_k  0.0702229     79
# 11   reanalysis_relative_humidity_percent  0.0697816      3
# 6                   reanalysis_avg_temp_k   0.057647     79
# 7             reanalysis_dew_point_temp_k  0.0510549      2
# 13  reanalysis_specific_humidity_g_per_kg  0.0504927     40
# 1                                 ndvi_nw  0.0296715     49

# %%
plt.figure(figsize=(16,9))
for i in (u'ndvi_ne', u'ndvi_nw', u'ndvi_se', u'ndvi_sw', u'ndvi_mean', u'precipitation_amt_mm',
       u'reanalysis_air_temp_k', u'reanalysis_avg_temp_k',
       u'reanalysis_dew_point_temp_k', u'reanalysis_max_air_temp_k',
       u'reanalysis_min_air_temp_k', u'reanalysis_precip_amt_kg_per_m2',
       u'reanalysis_relative_humidity_percent',
       u'reanalysis_sat_precip_amt_mm',
       u'reanalysis_specific_humidity_g_per_kg', u'reanalysis_tdtr_k',
       u'station_avg_temp_c', u'station_diur_temp_rng_c',
       u'station_max_temp_c', u'station_min_temp_c', u'station_precip_mm'):
    plt.plot(df_scores.T[i])
plt.title('Correlation of Rolling Mean of Features to Residuals', fontsize = 30)
plt.xlabel('Number of Weeks back to take Rolling Mean', fontsize=20)
plt.ylabel('Strength of Correlation (Absolute Value)', fontsize=20)
plt.legend(loc=(1,0), fontsize= 15)

# %%
plt.figure(figsize=(16,9))
for i in (u'ndvi_ne', u'ndvi_nw', u'ndvi_se', u'ndvi_sw'):
    plt.plot(df_scores.T[i])
plt.title('Correlation of Rolling Mean of Features to Residuals', fontsize = 30)
plt.xlabel('Number of Weeks back to take Rolling Mean', fontsize=20)
plt.ylabel('Strength of Correlation (Absolute Value)', fontsize=20)
plt.legend(loc=(1,0), fontsize= 15)

# %%
plt.figure(figsize=(16,9))
for i in (
       u'reanalysis_air_temp_k', u'reanalysis_avg_temp_k',
       u'reanalysis_dew_point_temp_k', u'reanalysis_max_air_temp_k',
       u'reanalysis_min_air_temp_k',
       u'station_avg_temp_c', u'station_diur_temp_rng_c',
       u'station_max_temp_c', u'station_min_temp_c'):
    plt.plot(df_scores.T[i])
plt.title('Correlation of Rolling Mean of Features to Residuals', fontsize = 30)
plt.xlabel('Number of Weeks back to take Rolling Mean', fontsize=20)
plt.ylabel('Strength of Correlation (Absolute Value)', fontsize=20)
plt.legend(loc=(1,0), fontsize= 15)

# %%
plt.figure(figsize=(16,9))
for i in (u'precipitation_amt_mm', u'station_precip_mm',
       u'reanalysis_precip_amt_kg_per_m2',
       u'reanalysis_relative_humidity_percent',
       u'reanalysis_sat_precip_amt_mm',
       u'reanalysis_specific_humidity_g_per_kg', u'reanalysis_tdtr_k'):
    plt.plot(df_scores.T[i])
plt.title('Correlation of Rolling Mean of Features to Residuals', fontsize = 30)
plt.xlabel('Number of Weeks back to take Rolling Mean', fontsize=20)
plt.ylabel('Strength of Correlation (Absolute Value)', fontsize=20)
plt.legend(loc=(1,0), fontsize= 15)

# %%
for i in range(1, 80):
    plt.plot(df_sj['reanalysis_sat_precip_amt_mm'].rolling(i, min_periods = 1).mean(), alpha = .25)
    plt.title('Rolling Mean of reanalysis_sat_precip_amt_mm - ' + str(i) + ' Week Window')
    plt.savefig('./corrplots/rolling' + str(i) + '.png')

# %% [markdown]
# ### Rolling Standard Deviations

# %%
# Plot sum of correlation between rolling std of all features and residuals
# create df of correlation between feature and resid at each rolling mean
df_scores = pd.DataFrame()
for i in range (2, 60):
    df = sj_train.drop(['month', 'weekofyear', 'month'], axis = 1)
    df = df.rolling(i, min_periods=1).std()
    df['resid'] = sj_residuals_train.values
    df_corr = df.corr()
    df_scores[str(i)] = df_corr['resid']

# %%
# create df of max absoute vaule of corr and the window
feature = []
abs_corr = []
window = []

for i in df_scores.T.drop('resid', axis = 1).columns:
    feature.append(i)
    abs_corr.append(max(abs(df_scores.T[i])))
    window.append(df_scores.T[abs(df_scores.T[i]) == max(abs(df_scores.T[i]))].index[0])

scores_df = pd.DataFrame([feature, abs_corr, window]).T
scores_df.columns = ('feature', 'abs_corr', 'window')
scores_df.sort_values('abs_corr', ascending = False)
# Out:
#                                   feature   abs_corr window
# 4                    precipitation_amt_mm   0.435727     58
# 12           reanalysis_sat_precip_amt_mm   0.435727     58
# 14                      reanalysis_tdtr_k   0.326759     59
# 7             reanalysis_dew_point_temp_k   0.318879     51
# 13  reanalysis_specific_humidity_g_per_kg   0.316754     50
# 5                   reanalysis_air_temp_k   0.296989     59
# 9               reanalysis_min_air_temp_k   0.287258     53
# 6                   reanalysis_avg_temp_k   0.285128     59
# 19                      station_precip_mm   0.277629     58
# 3                                 ndvi_sw   0.275159      7
# 8               reanalysis_max_air_temp_k   0.257391     59
# 1                                 ndvi_nw    0.25574      5
# 11   reanalysis_relative_humidity_percent   0.243984     50
# 0                                 ndvi_ne   0.237581      6
# 20                              ndvi_mean   0.217543      5
# 2                                 ndvi_se    0.20561      4
# 17                     station_max_temp_c   0.175837     59
# 16                station_diur_temp_rng_c   0.165235     56
# 10        reanalysis_precip_amt_kg_per_m2  0.0991256     41
# 18                     station_min_temp_c  0.0970514     18
# 15                     station_avg_temp_c  0.0961824     12

# %%
plt.figure(figsize=(20,12))
for i in (u'ndvi_ne', u'ndvi_nw', u'ndvi_se', u'ndvi_sw', u'ndvi_mean', u'precipitation_amt_mm',
       u'reanalysis_air_temp_k', u'reanalysis_avg_temp_k',
       u'reanalysis_dew_point_temp_k', u'reanalysis_max_air_temp_k',
       u'reanalysis_min_air_temp_k', u'reanalysis_precip_amt_kg_per_m2',
       u'reanalysis_relative_humidity_percent',
       u'reanalysis_sat_precip_amt_mm',
       u'reanalysis_specific_humidity_g_per_kg', u'reanalysis_tdtr_k',
       u'station_avg_temp_c', u'station_diur_temp_rng_c',
       u'station_max_temp_c', u'station_min_temp_c', u'station_precip_mm'):
    plt.plot(df_scores.T[i])
plt.title('Correlation of Rolling STD of Features to Residuals', fontsize = 30)
plt.xlabel('Number of Weeks back to take STD Mean', fontsize=20)
plt.ylabel('Strength of Correlation (Absolute Value)', fontsize=20)
plt.legend(loc=(1,0), fontsize= 15)

# %% [markdown]
# ### Shifted Back

# %%
# Plot sum of correlation between rolling std of all features and residuals
# create df of correlation between feature and resid at each rolling mean
df_scores = pd.DataFrame()
for i in range (2, 60):
    df = sj_train.drop(['month', 'weekofyear', 'month'], axis = 1)
    df = df.shift(i)[i:]
    df['resid'] = sj_residuals_train.values[i:]
    df_corr = df.corr()
    df_scores[str(i)] = df_corr['resid']

# %%
# create df of max absoute vaule of corr and the window
feature = []
abs_corr = []
window = []

for i in df_scores.T.drop('resid', axis = 1).columns:
    feature.append(i)
    abs_corr.append(max(abs(df_scores.T[i])))
    window.append(df_scores.T[abs(df_scores.T[i]) == max(abs(df_scores.T[i]))].index[0])

scores_df = pd.DataFrame([feature, abs_corr, window]).T
scores_df.columns = ('feature', 'abs_corr', 'window')
scores_df.sort_values('abs_corr', ascending = False)
# Out:
#                                   feature   abs_corr window
# 2                                 ndvi_se   0.192341      2
# 16                station_diur_temp_rng_c    0.16233     32
# 0                                 ndvi_ne   0.122723     32
# 17                     station_max_temp_c   0.122482      4
# 14                      reanalysis_tdtr_k   0.102876     51
# 12           reanalysis_sat_precip_amt_mm   0.100356     20
# 4                    precipitation_amt_mm   0.100356     20
# 18                     station_min_temp_c  0.0981376      5
# 15                     station_avg_temp_c  0.0961815      3
# 19                      station_precip_mm  0.0901375     56
# 3                                 ndvi_sw  0.0813403     14
# 11   reanalysis_relative_humidity_percent  0.0750241     52
# 20                              ndvi_mean  0.0731724      3
# 1                                 ndvi_nw  0.0723855     59
# 10        reanalysis_precip_amt_kg_per_m2  0.0671958     12
# 7             reanalysis_dew_point_temp_k  0.0579792     52
# 13  reanalysis_specific_humidity_g_per_kg  0.0564211     52
# 9               reanalysis_min_air_temp_k   0.054485     48
# 8               reanalysis_max_air_temp_k  0.0507431      2
# 6                   reanalysis_avg_temp_k  0.0502184     47
# 5                   reanalysis_air_temp_k  0.0478479     48

# %%
plt.figure(figsize=(20,12))
for i in (u'ndvi_ne', u'ndvi_nw', u'ndvi_se', u'ndvi_sw', u'ndvi_mean', u'precipitation_amt_mm',
       u'reanalysis_air_temp_k', u'reanalysis_avg_temp_k',
       u'reanalysis_dew_point_temp_k', u'reanalysis_max_air_temp_k',
       u'reanalysis_min_air_temp_k', u'reanalysis_precip_amt_kg_per_m2',
       u'reanalysis_relative_humidity_percent',
       u'reanalysis_sat_precip_amt_mm',
       u'reanalysis_specific_humidity_g_per_kg', u'reanalysis_tdtr_k',
       u'station_avg_temp_c', u'station_diur_temp_rng_c',
       u'station_max_temp_c', u'station_min_temp_c', u'station_precip_mm'):
    plt.plot(df_scores.T[i])
plt.title('Correlation of Weeks shifted back of Features to Residuals', fontsize = 30)
plt.xlabel('Number of Weeks shift back', fontsize=20)
plt.ylabel('Strength of Correlation (Absolute Value)', fontsize=20)
plt.legend(loc=(1,0), fontsize= 15)

# %% [markdown]
# ### Exponentially Weighted Mean

# %%
# Plot sum of correlation between rolling std of all features and residuals
# create df of correlation between feature and resid at each rolling mean
df_scores = pd.DataFrame()
for i in range (2, 60):
    df = sj_train.drop(['month', 'weekofyear', 'month'], axis = 1)
    df = df.ewm(span = i).mean()
    df['resid'] = sj_residuals_train.values
    df_corr = df.corr()
    df_scores[str(i)] = df_corr['resid']

# %%
# create df of max absoute vaule of corr and the window
feature = []
abs_corr = []
window = []

for i in df_scores.T.drop('resid', axis = 1).columns:
    feature.append(i)
    abs_corr.append(max(abs(df_scores.T[i])))
    window.append(df_scores.T[abs(df_scores.T[i]) == max(abs(df_scores.T[i]))].index[0])

scores_df = pd.DataFrame([feature, abs_corr, window]).T
scores_df.columns = ('feature', 'abs_corr', 'window')
scores_df.sort_values('abs_corr', ascending = False)
# Out:
#                                   feature   abs_corr window
# 2                                 ndvi_se   0.373408     17
# 4                    precipitation_amt_mm   0.299287     59
# 12           reanalysis_sat_precip_amt_mm   0.299287     59
# 19                      station_precip_mm   0.266004     59
# 17                     station_max_temp_c   0.176128     35
# 14                      reanalysis_tdtr_k   0.139549     59
# 15                     station_avg_temp_c   0.126367     59
# 18                     station_min_temp_c   0.122517     33
# 16                station_diur_temp_rng_c   0.121867     59
# 20                              ndvi_mean   0.103836     16
# 3                                 ndvi_sw  0.0894538     59
# 8               reanalysis_max_air_temp_k  0.0759883      2
# 11   reanalysis_relative_humidity_percent  0.0698048      2
# 0                                 ndvi_ne  0.0663212      8
# 10        reanalysis_precip_amt_kg_per_m2   0.057305     42
# 7             reanalysis_dew_point_temp_k  0.0521514      2
# 13  reanalysis_specific_humidity_g_per_kg  0.0507041      2
# 9               reanalysis_min_air_temp_k  0.0434453      2
# 6                   reanalysis_avg_temp_k  0.0330535      2
# 5                   reanalysis_air_temp_k  0.0323716      2
# 1                                 ndvi_nw  0.0190042     37

# %%
plt.figure(figsize=(20,12))
for i in (u'ndvi_ne', u'ndvi_nw', u'ndvi_se', u'ndvi_sw', u'ndvi_mean', u'precipitation_amt_mm',
       u'reanalysis_air_temp_k', u'reanalysis_avg_temp_k',
       u'reanalysis_dew_point_temp_k', u'reanalysis_max_air_temp_k',
       u'reanalysis_min_air_temp_k', u'reanalysis_precip_amt_kg_per_m2',
       u'reanalysis_relative_humidity_percent',
       u'reanalysis_sat_precip_amt_mm',
       u'reanalysis_specific_humidity_g_per_kg', u'reanalysis_tdtr_k',
       u'station_avg_temp_c', u'station_diur_temp_rng_c',
       u'station_max_temp_c', u'station_min_temp_c', u'station_precip_mm'):
    plt.plot(df_scores.T[i])
plt.title('Correlation of Exponentially Weighted Mean of Features to Residuals', fontsize = 30)
plt.xlabel('Number of Weeks back to take Exponentially Weighted Mean', fontsize=20)
plt.ylabel('Strength of Correlation (Absolute Value)', fontsize=20)
plt.legend(loc=(1,0), fontsize= 15)

# %% [markdown]
# ### Notes here:
# * rolling mean of all temp vars should be of ~50 observations. That is about 1 full year
# * shifted back should be around 30 observations
# * should i do a variation of this test for each feature? weeks rolled back should depend on the feature, not featureset as a whole

# %% [markdown]
# ## Test on valid from grid search results
# use values from 3 tables above

# %%
# munge data

# max roll back set to 59

# rolling means df
Xtrain_means1 = df_sj['station_avg_temp_c'].rolling(window = 52).mean()[60:675]
Xtrain_means2 = df_sj['ndvi_ne'].rolling(window = 53).mean()[60:675]
Xtrain_means3 = df_sj['ndvi_sw'].rolling(window = 2).mean()[60:675]
Xtrain_means4 = df_sj['reanalysis_relative_humidity_percent'].rolling(window = 2).mean()[60:675]

# exponentially weighted means
Xtrain_xmeans1 = df_sj['station_avg_temp_c'].ewm(span = 53).mean()[60:675]

# rolling stds df
Xtrain_std1 = df_sj['reanalysis_avg_temp_k'].rolling(window = 2).std()[60:675]

# combine all dfs
Xtrain = pd.concat([Xtrain_means1, Xtrain_means2, Xtrain_means3, Xtrain_means4, Xtrain_std1], axis = 1)
ytrain = sj_residuals_train[60:]

print len(Xtrain), len(ytrain)

# rolling means df
Xvalid_means1 = df_sj['station_avg_temp_c'].rolling(window = 53).mean()[675:936]
Xvalid_means2 = df_sj['ndvi_ne'].rolling(window = 53).mean()[675:936]
Xvalid_means3 = df_sj['ndvi_sw'].rolling(window = 2).mean()[675:936]
Xvalid_means4 = df_sj['reanalysis_relative_humidity_percent'].rolling(window = 2).mean()[675:936]

# exponentially weighted means
Xvalid_xmeans1 = df_sj['station_avg_temp_c'].ewm(span = 53).mean()[675:936]

# rolling stds df
Xvalid_std1 = df_sj['reanalysis_avg_temp_k'].rolling(window = 2).std()[675:936]

# combine all dfs
Xvalid = pd.concat([Xvalid_means1, Xvalid_means2, Xvalid_means3, Xvalid_means4, Xvalid_std1], axis = 1)[60:]
yvalid = sj_residuals_test[60:]

print len(Xvalid), len(yvalid)

# fit on model, predict
lr_sj_residual = LinearRegression()
lr_sj_residual.fit(Xtrain, ytrain)

sj_valid_preds = lr_sj_residual.predict(Xvalid)

print mean_absolute_error(sj_valid_preds, yvalid)
print lr_sj_residual.score(Xvalid, yvalid)
plt.plot(yvalid.values)
plt.plot(sj_valid_preds)
# Out:
# 615 615
# 201 201
# 20.3742379306
# 0.156748573383

# %% [markdown]
# ### Notes:
#
# * I will slowly add more features to this graph

# %% [markdown]
# ### Test grid searched rollback terms on actual cases
# Add the monthly trend and the predicted residuals to get predicted cases

# %%
preds_df = pd.DataFrame({'pred_resid':sj_valid_preds,
                         'real_resid':yvalid,
                         'monthly_trend':sj_predicts[60:],
                         'actual_cases':ytest[60:]})
preds_df['pred_cases'] = preds_df['monthly_trend'] + preds_df['pred_resid']
preds_df['pred_cases'] = preds_df['pred_cases'].apply(lambda x: int(x)).apply(lambda x: 0 if x < 0 else x)

# %%
print 'predicted and actual MAE:'
print mean_absolute_error(preds_df['pred_cases'], preds_df['actual_cases'])
print 'monthly trend and actual MAE:'
print mean_absolute_error(preds_df['monthly_trend'], preds_df['actual_cases'])
preds_df[['monthly_trend', 'actual_cases', 'pred_cases']].plot(figsize=(14,3))
# Out:
# predicted and actual MAE:
# 18.4228855721
# monthly trend and actual MAE:
# 26.6082089552

# %% [markdown]
# ## IQ
#
# Do the same as I did for SJ above, but to see which IQ features explain the variance in the residuals.

# %%
print len(pd.get_dummies(iq_Xtrain['month'], prefix='month')), len(iq_ytrain.values)
print len(pd.get_dummies(iq_Xvalid['month'], prefix='month')), len(iq_yvalid.values)
# Out:
# 364 364
# 156 156

# %%
# iq monthly trend

lr_iq = LinearRegression()
X = pd.get_dummies(iq_Xtrain['month'], prefix='month')
y = iq_ytrain.values

lr_iq.fit(X, y)
monthly_trend_train = pd.Series(lr_iq.predict(X)).rolling(9, min_periods = 1).mean()
iq_residuals_train = y - monthly_trend_train


# on validation data
# note: monthly trend does not need previous weeks data, so this can use the validation set
Xtest = pd.get_dummies(iq_Xvalid['month'], prefix='month')
ytest = iq_yvalid.values
monthly_trend_valid = pd.Series(lr_iq.predict(Xtest)).rolling(9, min_periods=1).mean()
iq_residuals_test = ytest - monthly_trend_valid

# plot
plt.plot(lr_iq.predict(Xtest))
plt.plot(monthly_trend_valid)
plt.plot(ytest)
plt.show()

print mean_absolute_error(lr_iq.predict(Xtest), ytest)
print mean_absolute_error(monthly_trend_valid, ytest)
# Out:
# 7.0661005661
# 6.93198985208

# %%
# Find the residuals of the monthly trend

plt.figure(figsize=(16, 4))
plt.plot(iq_residuals_test, label = 'residuals', linewidth = 3)
plt.plot(ytest, 'g-*', alpha = .4, label = 'true values')
plt.plot(monthly_trend_valid, alpha = .4, label = 'monthly trend')
plt.title('True Values, Monthly Trend, and Residuals of Dengue Cases in Iquitos, Peru')
plt.legend()
print np.mean(iq_residuals_test)

## PREDICT THE BLUE!!!
# Note: the monthly predictions for iq are pretty bad over the validation set...
# Out:
# 3.43545635912

# %% [markdown]
# ## See how far back we should roll in Iquitos weather

# %% [markdown]
# ### Rolling Mean

# %%
# Plot sum of correlation between rolling mean of all features and residuals
mean_score = []
for i in range (2, 60):
    df = iq_train.drop(['month', 'weekofyear'], axis = 1)
    df = df.rolling(i).mean()[i-1:]
    df['resid'] = iq_residuals_train.values[i-1:]

    mean_score.append(abs(df.corr()['resid']).sum()-1)
plt.plot(mean_score)

# %%
# Plot sum of correlation between rolling mean of all features and residuals
# create df of correlation between feature and resid at each rolling mean
df_scores = pd.DataFrame()
for i in range (2, 80):
    df = iq_train.drop(['month', 'weekofyear', 'month'], axis = 1)
    df = df.rolling(i, min_periods=1).mean()
    df['resid'] = iq_residuals_train.values
    df_corr = df.corr()
    df_scores[str(i)] = df_corr['resid']

# %%
# create df of max absolute value of corr and the window
feature = []
abs_corr = []
window = []

for i in df_scores.T.drop('resid', axis = 1).columns:
    feature.append(i)
    abs_corr.append(max(abs(df_scores.T[i])))
    window.append(df_scores.T[abs(df_scores.T[i]) == max(abs(df_scores.T[i]))].index[0])

scores_df = pd.DataFrame([feature, abs_corr, window]).T
scores_df.columns = ('feature', 'abs_corr', 'window')
scores_df.sort_values('abs_corr', ascending = False)
# Out:
#                                   feature   abs_corr window
# 2                                 ndvi_se   0.354635     42
# 7             reanalysis_dew_point_temp_k   0.299721     54
# 13  reanalysis_specific_humidity_g_per_kg   0.297681     55
# 9               reanalysis_min_air_temp_k   0.291042     53
# 14                      reanalysis_tdtr_k   0.286716     52
# 11   reanalysis_relative_humidity_percent    0.27151     53
# 8               reanalysis_max_air_temp_k   0.261243     51
# 3                                 ndvi_sw   0.245326     65
# 1                                 ndvi_nw   0.242303     60
# 10        reanalysis_precip_amt_kg_per_m2   0.232075     57
# 16                station_diur_temp_rng_c    0.20318     51
# 17                     station_max_temp_c   0.183099     36
# 20                              ndvi_mean   0.175392     45
# 19                      station_precip_mm   0.167562     31
# 12           reanalysis_sat_precip_amt_mm   0.161267     56
# 4                    precipitation_amt_mm   0.161267     56
# 18                     station_min_temp_c   0.136642     56
# 15                     station_avg_temp_c   0.132824     63
# 6                   reanalysis_avg_temp_k   0.125557     79
# 5                   reanalysis_air_temp_k  0.0975733     79
# 0                                 ndvi_ne  0.0892751     69

# %%
plt.figure(figsize=(16,9))
for i in (u'ndvi_ne', u'ndvi_nw', u'ndvi_se', u'ndvi_sw', u'ndvi_mean', u'precipitation_amt_mm',
       u'reanalysis_air_temp_k', u'reanalysis_avg_temp_k',
       u'reanalysis_dew_point_temp_k', u'reanalysis_max_air_temp_k',
       u'reanalysis_min_air_temp_k', u'reanalysis_precip_amt_kg_per_m2',
       u'reanalysis_relative_humidity_percent',
       u'reanalysis_sat_precip_amt_mm',
       u'reanalysis_specific_humidity_g_per_kg', u'reanalysis_tdtr_k',
       u'station_avg_temp_c', u'station_diur_temp_rng_c',
       u'station_max_temp_c', u'station_min_temp_c', u'station_precip_mm'):
    plt.plot(df_scores.T[i])
plt.title('Correlation of Rolling Mean of Features to Residuals', fontsize = 30)
plt.xlabel('Number of Weeks back to take Rolling Mean', fontsize=20)
plt.ylabel('Strength of Correlation', fontsize=20)
plt.legend(loc=(1,0), fontsize= 15)

# %% [markdown]
# ### Rolling Standard Deviations

# %%
# Plot sum of correlation between rolling mean of all features and residuals
# create df of correlation between feature and resid at each rolling mean
df_scores = pd.DataFrame()
for i in range (2, 80):
    df = iq_train.drop(['month', 'weekofyear', 'month'], axis = 1)
    df = df.rolling(i, min_periods=1).std()
    df['resid'] = iq_residuals_train.values
    df_corr = df.corr()
    df_scores[str(i)] = df_corr['resid']

# %%
# create df of max absolute value of corr and the window
feature = []
abs_corr = []
window = []

for i in df_scores.T.drop('resid', axis = 1).columns:
    feature.append(i)
    abs_corr.append(max(abs(df_scores.T[i])))
    window.append(df_scores.T[abs(df_scores.T[i]) == max(abs(df_scores.T[i]))].index[0])

scores_df = pd.DataFrame([feature, abs_corr, window]).T
scores_df.columns = ('feature', 'abs_corr', 'window')
scores_df.sort_values('abs_corr', ascending = False)
# Out:
#                                   feature   abs_corr window
# 19                      station_precip_mm   0.397782     31
# 1                                 ndvi_nw   0.280776     73
# 5                   reanalysis_air_temp_k   0.242381     40
# 6                   reanalysis_avg_temp_k   0.210136     41
# 11   reanalysis_relative_humidity_percent   0.199102     79
# 3                                 ndvi_sw   0.193416     62
# 20                              ndvi_mean   0.178748     11
# 16                station_diur_temp_rng_c   0.178496     30
# 4                    precipitation_amt_mm   0.171725     47
# 12           reanalysis_sat_precip_amt_mm   0.171725     47
# 17                     station_max_temp_c   0.171366     24
# 15                     station_avg_temp_c   0.169141     46
# 18                     station_min_temp_c    0.16434     56
# 2                                 ndvi_se   0.163919     33
# 14                      reanalysis_tdtr_k   0.163013      5
# 10        reanalysis_precip_amt_kg_per_m2   0.151379     21
# 13  reanalysis_specific_humidity_g_per_kg   0.144086     73
# 9               reanalysis_min_air_temp_k   0.118271     18
# 0                                 ndvi_ne  0.0970217     62
# 7             reanalysis_dew_point_temp_k  0.0964504      4
# 8               reanalysis_max_air_temp_k  0.0933119      7

# %%
plt.figure(figsize=(16,9))
for i in (u'ndvi_ne', u'ndvi_nw', u'ndvi_se', u'ndvi_sw', u'ndvi_mean', u'precipitation_amt_mm',
       u'reanalysis_air_temp_k', u'reanalysis_avg_temp_k',
       u'reanalysis_dew_point_temp_k', u'reanalysis_max_air_temp_k',
       u'reanalysis_min_air_temp_k', u'reanalysis_precip_amt_kg_per_m2',
       u'reanalysis_relative_humidity_percent',
       u'reanalysis_sat_precip_amt_mm',
       u'reanalysis_specific_humidity_g_per_kg', u'reanalysis_tdtr_k',
       u'station_avg_temp_c', u'station_diur_temp_rng_c',
       u'station_max_temp_c', u'station_min_temp_c', u'station_precip_mm'):
    plt.plot(df_scores.T[i])
plt.title('Correlation of Rolling Mean of Features to Residuals', fontsize = 30)
plt.xlabel('Number of Weeks back to take Rolling Mean', fontsize=20)
plt.ylabel('Strength of Correlation', fontsize=20)
plt.legend(loc=(1,0), fontsize= 15)

# %% [markdown]
# ### Notes on how far back to roll in IQ:
# * rolling mean should be of ~50 observations. That is about 1 full year
# * rolling std should be 30 for precipitation?

# %% [markdown]
# ## predict the residuals based on rolling weather features

# %%
df_iq.columns

# %%
len(Xtrain)
len(ytrain)
# Out:
# 252

# %%
# rolling mean of feature to predict residuals

# munge data

# max roll back set to 59

# set up training data
# rolling means df
Xtrain_means1 = df_iq['ndvi_se'].rolling(window = 45).mean()[60:364]
Xtrain_means2 = df_iq['reanalysis_min_air_temp_k'].rolling(window = 5).mean()[60:364]
Xtrain_means3 = df_iq['reanalysis_relative_humidity_percent'].rolling(window = 14).mean()[60:364]
Xtrain_means4 = df_iq['station_precip_mm'].rolling(window = 6).mean()[60:364]

# rolling stds df
Xtrain_std1 = df_iq['station_precip_mm'].rolling(window = 31).std()[60:364]

# weeks shifted back
Xtrain_shift1 = df_iq['station_min_temp_c'].shift(2)[60:364]
Xtrain_shift2 = df_iq['station_precip_mm'].shift(1)[60:364]


# combine all dfs
Xtrain = pd.concat([Xtrain_means1, Xtrain_std1], axis = 1)
ytrain = iq_residuals_train[60:]

print len(Xtrain), len(ytrain)

# set up validation data
# rolling means df
Xvalid_means1 = df_iq['ndvi_se'].rolling(window = 45).mean()[364:520]
Xvalid_means2 = df_iq['reanalysis_min_air_temp_k'].rolling(window = 5).mean()[364:520]
Xvalid_means3 = df_iq['reanalysis_relative_humidity_percent'].rolling(window = 14).mean()[364:520]
Xvalid_means4 = df_iq['station_precip_mm'].rolling(window = 6).mean()[364:520]

# rolling stds df
Xvalid_std1 = df_iq['station_precip_mm'].rolling(window = 31).std()[364:520]

# weeks shifted back
Xvalid_shift1 = df_iq['station_min_temp_c'].shift(2)[364:520]
Xvalid_shift2 = df_iq['station_precip_mm'].shift(1)[364:520]

# combine all dfs
Xvalid = pd.concat([Xvalid_means1, Xvalid_std1], axis = 1)[60:]
yvalid = iq_residuals_test[60:]

print len(Xvalid), len(yvalid)

# model it!

lr_iq_resids = LinearRegression()
lr_iq_resids.fit(Xtrain, ytrain)

iq_valid_preds = lr_iq_resids.predict(Xvalid)

# plot iq residual predictions
plt.plot(yvalid.values, alpha = .75)
plt.plot(iq_valid_preds)
print lr_iq_resids.score(Xvalid, yvalid)
print mean_absolute_error(iq_valid_preds, yvalid)
# Out:
# 304 304
# 96 96
# -0.215661595842
# 7.8346443317

# %% [markdown]
# ### Notes:
#
# * IQ resiuduals is much more erratic and harder to predict
# * Tweak these features more

# %% [markdown]
# ## USE TEST DATA, MAKE CSV OF SUBMISSIONS
#
# Need to use full dataset (train + test) because values depend on previous weather data

# %%
# transform sj data

month_dums = pd.get_dummies(df_sj['month'], prefix='month')
temp_roll_means = pd.DataFrame(df_sj[['station_avg_temp_c']].rolling(window = 55).mean())
# temp_roll_std = pd.DataFrame(df_sj[['station_avg_temp_c', 'precipitation_amt_mm']].rolling(window = 8).mean())

# combine into test set
Xtest = pd.concat([month_dums, temp_roll_means], axis = 1)

# train model
lr_sj_full = LinearRegression()
lr_sj_full.fit(Xtest[60:-260], cases_sj.values[60:])

# predicts
sj_full_preds = lr_sj_full.predict(Xtest[55:])
sj_submit_preds = sj_full_preds[-260:]

# %%
# transform iq data
month_dums = pd.get_dummies(df_iq['month'], prefix='month')
temp_roll_means = pd.DataFrame(df_iq[['ndvi_nw']].rolling(window = 68).mean())
# temp_roll_std = pd.DataFrame(df_iq[['station_avg_temp_c', 'precipitation_amt_mm']].rolling(window = 8).mean())

# combine into test
Xtest = pd.concat([month_dums, temp_roll_means], axis = 1)

# train
lr_iq_full = LinearRegression()
lr_iq_full.fit(Xtest[68:-156], cases_iq.values[68:])

# predicts
iq_full_preds = lr_iq_full.predict(Xtest[68:])
iq_submit_preds = iq_full_preds[-156:]

# %%
plt.plot(sj_submit_preds)
plt.show()
plt.plot(iq_submit_preds)
plt.show()

# %%
total_preds = list(sj_submit_preds) + list(iq_submit_preds)

# %% [markdown]
# ### make csv

# %%
# submission
submission_format = pd.read_csv('./datasets/submission_format.csv')

# %%
submission_format['total_cases'] = total_preds
submission_format['total_cases'] = submission_format['total_cases'].apply(lambda x: int(x))

# %%
# Save to CSV, use current date
submission_format.to_csv('submissions/dengue_submission_9_12_17v1.csv', index=False)

# %% [markdown]
# ## Make predictions v2
# Predict the residuals, then add them to the monthly trend

# %% [markdown]
# ### San Juan

# %%
# get monthly trend of whole test df
lr_sj_month = LinearRegression()
X_months = pd.get_dummies(df_sj['month'], prefix='month')[:936]
Xtest_months = pd.get_dummies(df_sj['month'], prefix='month')[936:]
y = cases_sj.values

lr_sj_month.fit(X_months, y)
monthly_trend = pd.Series(lr_sj_month.predict(X_months)).rolling(3, min_periods=1).mean()
sj_residuals_all = y - monthly_trend

# create test df of rolling weather stats
# rolling means df
Xtrain_means1 = df_sj['station_avg_temp_c'].rolling(window = 53).mean()[60:936]
Xtrain_means2 = df_sj['ndvi_ne'].rolling(window = 53).mean()[60:936]
Xtrain_means3 = df_sj['ndvi_sw'].rolling(window = 2).mean()[60:936]
Xtrain_means4 = df_sj['reanalysis_relative_humidity_percent'].rolling(window = 2).mean()[60:936]

# exponentially weighted means
Xtrain_xmeans1 = df_sj.ewm(span = 30).mean()[60:936]

# rolling stds df
Xtrain_std1 = df_sj['reanalysis_avg_temp_k'].rolling(window = 2).std()[60:936]

# combine all dfs
Xtrain = pd.concat([Xtrain_means1], axis = 1)
ytrain = sj_residuals_all[60:]


# create test df on rolling weather stats
# rolling means df
Xtest_means1 = df_sj['station_avg_temp_c'].rolling(window = 53).mean()[936:]
Xtest_means2 = df_sj['ndvi_ne'].rolling(window = 53).mean()[936:]
Xtest_means3 = df_sj['ndvi_sw'].rolling(window = 2).mean()[936:]
Xtest_means4 = df_sj['reanalysis_relative_humidity_percent'].rolling(window = 2).mean()[936:]

# exponentially weighted means
Xtest_xmeans1 = df_sj.ewm(span = 30).mean()[936:]

# rolling stds df
Xtest_std1 = df_sj['reanalysis_avg_temp_k'].rolling(window = 2).std()[936:]

# combine all dfs
Xtest_weather = pd.concat([Xtest_means1], axis = 1)

# fit on model
lr_sj_resid = LinearRegression()
lr_sj_resid.fit(Xtrain, ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# make predictions on monthly data and residual data
sj_monthly_preds = pd.Series(lr_sj_month.predict(Xtest_months)).rolling(3, min_periods=1).mean()
sj_resid_preds = lr_sj_resid.predict(Xtest_weather)
sj_cases_pred = pd.Series(sj_resid_preds + sj_monthly_preds).rolling(1, min_periods=1).mean()
sj_cases_pred = sj_cases_pred.apply(lambda x: 1 if x < 1 else int(x))

# %%
# plt.plot(sj_resid_preds)
plt.plot(sj_monthly_preds)
plt.plot(sj_cases_pred)

# %% [markdown]
# ### Iquitos

# %%
len(cases_iq)
# Out:
# 520

# %%
df_iq.ewm(span=5).mean().head()
# Out:
#                  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# week_start_date
# 2000-07-01        26.000000  0.192886  0.132257  0.340886  0.247200
# 2000-07-08        26.600000  0.207254  0.218563  0.310029  0.243874
# 2000-07-15        27.263158  0.192808  0.197041  0.259859  0.188993
# 2000-07-22        27.984615  0.207314  0.175602  0.257508  0.193696
# 2000-07-29        28.758294  0.253890  0.231852  0.256304  0.257938
#
#                  precipitation_amt_mm  reanalysis_air_temp_k  \
# week_start_date
# 2000-07-01                  25.410000             296.740000
# 2000-07-08                  46.530000             296.676571
# 2000-07-15                  50.788421             296.553008
# 2000-07-22                  32.017846             296.056264
# 2000-07-29                  43.819336             296.200833
#
#                  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# week_start_date
# 2000-07-01                  298.450000                   295.184286
# 2000-07-08                  298.437143                   295.288857
# 2000-07-15                  297.942481                   295.447068
# 2000-07-22                  297.230549                   294.346330
# 2000-07-29                  297.386087                   294.196926
#
#                  reanalysis_max_air_temp_k    ...      \
# week_start_date                               ...
# 2000-07-01                      307.300000    ...
# 2000-07-08                      306.880000    ...
# 2000-07-15                      305.752632    ...
# 2000-07-22                      304.858462    ...
# 2000-07-29                      305.680569    ...
#
#                  reanalysis_sat_precip_amt_mm  \
# week_start_date
# 2000-07-01                          25.410000
# 2000-07-08                          46.530000
# 2000-07-15                          50.788421
# 2000-07-22                          32.017846
# 2000-07-29                          43.819336
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# week_start_date
# 2000-07-01                                   16.651429           8.928571
# 2000-07-08                                   16.778286           9.760000
# 2000-07-15                                   16.940150           8.635338
# 2000-07-22                                   15.898066           8.834286
# 2000-07-29                                   15.723866           9.089844
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# week_start_date
# 2000-07-01                26.400000                10.775000
# 2000-07-08                26.700000                11.250000
# 2000-07-15                26.747368                11.352632
# 2000-07-22                26.340000                11.012308
# 2000-07-29                26.439810                11.191848
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm  \
# week_start_date
# 2000-07-01                32.500000           20.700000           3.000000
# 2000-07-08                33.400000           20.760000          34.560000
# 2000-07-15                33.210526           20.731579          36.236842
# 2000-07-22                32.500000           18.226154          33.646154
# 2000-07-29                32.807109           18.561611          22.265403
#
#                  month  ndvi_mean
# week_start_date
# 2000-07-01         7.0   0.228307
# 2000-07-08         7.0   0.244930
# 2000-07-15         7.0   0.209675
# 2000-07-22         7.0   0.208530
# 2000-07-29         7.0   0.249996
#
# [5 rows x 23 columns]

# %%
df_iq.ewm(span=2).mean().head()
# Out:
#                  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# week_start_date
# 2000-07-01        26.000000  0.192886  0.132257  0.340886  0.247200
# 2000-07-08        26.750000  0.210846  0.240139  0.302314  0.243043
# 2000-07-15        27.615385  0.187246  0.193747  0.234330  0.163408
# 2000-07-22        28.550000  0.214572  0.161132  0.247742  0.188320
# 2000-07-29        29.520661  0.290933  0.268907  0.252180  0.303944
#
#                  precipitation_amt_mm  reanalysis_air_temp_k  \
# week_start_date
# 2000-07-01                  25.410000             296.740000
# 2000-07-08                  51.810000             296.660714
# 2000-07-15                  54.378462             296.491099
# 2000-07-22                  21.453000             295.725679
# 2000-07-29                  49.104793             296.199079
#
#                  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# week_start_date
# 2000-07-01                  298.450000                   295.184286
# 2000-07-08                  298.433929                   295.315000
# 2000-07-15                  297.713187                   295.528132
# 2000-07-22                  296.711071                   293.684714
# 2000-07-29                  297.330047                   293.867084
#
#                  reanalysis_max_air_temp_k    ...      \
# week_start_date                               ...
# 2000-07-01                      307.300000    ...
# 2000-07-08                      306.775000    ...
# 2000-07-15                      305.200000    ...
# 2000-07-22                      304.120000    ...
# 2000-07-29                      306.047934    ...
#
#                  reanalysis_sat_precip_amt_mm  \
# week_start_date
# 2000-07-01                          25.410000
# 2000-07-08                          51.810000
# 2000-07-15                          54.378462
# 2000-07-22                          21.453000
# 2000-07-29                          49.104793
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# week_start_date
# 2000-07-01                                   16.651429           8.928571
# 2000-07-08                                   16.810000           9.967857
# 2000-07-15                                   17.024615           8.180220
# 2000-07-22                                   15.274214           8.810714
# 2000-07-29                                   15.388064           9.272137
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# week_start_date
# 2000-07-01                26.400000                10.775000
# 2000-07-08                26.775000                11.368750
# 2000-07-15                26.792308                11.436538
# 2000-07-22                26.100000                10.826875
# 2000-07-29                26.434711                11.264091
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm  \
# week_start_date
# 2000-07-01                32.500000           20.700000           3.000000
# 2000-07-08                33.625000           20.775000          42.450000
# 2000-07-15                33.192308           20.723077          39.438462
# 2000-07-22                32.050000           16.657500          33.067500
# 2000-07-29                32.886777           18.292562          13.609091
#
#                  month  ndvi_mean
# week_start_date
# 2000-07-01         7.0   0.228307
# 2000-07-08         7.0   0.249086
# 2000-07-15         7.0   0.194683
# 2000-07-22         7.0   0.202941
# 2000-07-29         7.0   0.278991
#
# [5 rows x 23 columns]

# %%
# get monthly trend of whole test df
lr_iq_month = LinearRegression()
X_months = pd.get_dummies(df_iq['month'], prefix='month')[:520]
Xtest_months = pd.get_dummies(df_iq['month'], prefix='month')[520:]
y = cases_iq.values

lr_iq_month.fit(X_months, y)
monthly_trend = pd.Series(lr_iq_month.predict(X_months)).rolling(8, min_periods=1).mean()
iq_residuals_all = y - monthly_trend

# create test df of rolling weather stats
# rolling means df
Xtrain_means1 = df_iq['ndvi_nw'].rolling(window = 53).mean()[60:520]
Xtrain_means2 = df_iq['station_avg_temp_c'].rolling(window = 53).mean()[60:520]
Xtrain_means3 = df_iq['reanalysis_relative_humidity_percent'].rolling(window = 14).mean()[60:520]
Xtrain_means4 = df_iq['station_precip_mm'].rolling(window = 6).mean()[60:520]

# rolling stds df
Xtrain_std1 = df_iq['station_precip_mm'].rolling(window = 31).std()[60:520]

# weeks shifted back
Xtrain_shift1 = df_iq['station_min_temp_c'].shift(2)[60:520]
Xtrain_shift2 = df_iq['station_precip_mm'].shift(4)[60:520]


# combine all dfs
Xtrain = pd.concat([Xtrain_means2], axis = 1)
ytrain = iq_residuals_all[60:]


# create test df on rolling weather stats
# rolling means df
Xtest_means1 = df_iq['ndvi_nw'].rolling(window = 53).mean()[520:]
Xtest_means2 = df_iq['station_avg_temp_c'].rolling(window = 53).mean()[520:]
Xtest_means3 = df_iq['reanalysis_relative_humidity_percent'].rolling(window = 14).mean()[520:]
Xtest_means4 = df_iq['station_precip_mm'].rolling(window = 6).mean()[520:]

# rolling stds df
Xtest_std1 = df_iq['station_precip_mm'].rolling(window = 31).std()[520:]

# weeks shifted back
Xtest_shift1 = df_iq['station_min_temp_c'].shift(2)[520:]
Xtest_shift2 = df_iq['station_precip_mm'].shift(4)[520:]


# combine all dfs
Xtest_weather = pd.concat([Xtest_means2], axis = 1)

# fit on model
lr_iq_resid = LinearRegression()
lr_iq_resid.fit(Xtrain, ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# make predictions on monthly data and residual data
iq_monthly_preds = pd.Series(lr_iq_month.predict(Xtest_months)).rolling(8, min_periods=1).mean()
iq_resid_preds = lr_iq_resid.predict(Xtest_weather)
iq_cases_pred = pd.Series(iq_monthly_preds + iq_resid_preds)
iq_cases_pred = iq_cases_pred.apply(lambda x: 0 if x < 1 else int(x))

# %%
plt.plot(iq_resid_preds)
plt.plot(iq_monthly_preds)
plt.plot(iq_cases_pred)

# %% [markdown]
# ### make csv

# %%
total_preds = list(sj_cases_pred) + list(iq_cases_pred)

# %%
# submission
submission_format = pd.read_csv('./datasets/submission_format.csv')

# %%
submission_format['total_cases'] = total_preds
submission_format['total_cases'] = submission_format['total_cases'].apply(lambda x: int(x))

# %%
# Save to CSV, use current date
submission_format.to_csv('submissions/dengue_submission_9_17_17v1.csv', index=False)

# %%
submission_format.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  2008          18            1
# 1   sj  2008          19            1
# 2   sj  2008          20            1
# 3   sj  2008          21            1
# 4   sj  2008          22            1

# %% [markdown]
# ### Submitted MAEs!!!!
# * monthly trend and mean `station_avg_temp_c` with window = 52 was 20.7764
# * monthly trend and mean `station_avg_temp_c` with window = 52 and std window = 8 was 20.7981
# * monthly trend and mean `station_avg_temp_c` and `precipitation_amt_mm` with window = 52 and std window = 8 was 24.1274
# * monthly trend and sj used mean `station_avg_temp_c` with window = 55 and iq used 'ndvi_nw' with window = 68 was 23.5697
# * sj: monthly + multiple weather rollbacks. iq: monthly + `station_avg_temp_c` rolled back 52 was 21.9447
# * Next steps: use other rolling features (and std? and shifted? and exponentially weighted mean?)
